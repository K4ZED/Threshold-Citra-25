# %%
from google.colab import files
import cv2
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
for filename in uploaded.keys():
    img_path = filename
# Out:
#      <input type="file" id="files-d9c3c922-025c-42e1-a1af-4572c517a13d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9c3c922-025c-42e1-a1af-4572c517a13d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread(img_path)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.title('Citra Asli (RGB)')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Citra Grayscale')
plt.imshow(gray, cmap='gray')
plt.axis('off')

plt.show()

# %%
T = 100
_, hasil = cv2.threshold(gray, T, 255, cv2.THRESH_BINARY)

plt.title(f'Hasil Threshold (T={T})')
plt.imshow(hasil, cmap='gray')
plt.axis('off')
plt.show()

# %%
T = 120
_, hasil = cv2.threshold(gray, T, 255, cv2.THRESH_BINARY)

plt.title(f'Hasil Threshold (T={T})')
plt.imshow(hasil, cmap='gray')
plt.axis('off')
plt.show()

# %%
T = 140
_, hasil = cv2.threshold(gray, T, 255, cv2.THRESH_BINARY)

plt.title(f'Hasil Threshold (T={T})')
plt.imshow(hasil, cmap='gray')
plt.axis('off')
plt.show()

# %%
T = 160
_, hasil = cv2.threshold(gray, T, 255, cv2.THRESH_BINARY)

plt.title(f'Hasil Threshold (T={T})')
plt.imshow(hasil, cmap='gray')
plt.axis('off')
plt.show()
